# %%
import sys
from PyQt5.QtCore import *
from PyQt5.QtGui import *
from PyQt5.QtWidgets import *
import math
import random
class SliderDemo(QWidget):
    def __init__(self, parent=None):
        super(SliderDemo, self).__init__(parent)
        self.setWindowTitle("QSlider 例子")
        self.resize(300, 100)
        self.timer=QTimer()
        # self.timer.timeout.connect(self.timerf)
        self.timer.start(200)
        layout = QVBoxLayout()
        self.l1 = QLabel("Hello PyQt5")
        self.l1.setAlignment(Qt.AlignCenter)
        layout.addWidget(self.l1)
        # 水平方向
        self.sl = QSlider(Qt.Horizontal)
        # 设置最小值
        self.sl.setMinimum(10)
        # 设置最大值
        self.sl.setMaximum(50)
        # 步长
        self.sl.setSingleStep(3)
        # 设置当前值
        self.sl.setValue(20)
        # 刻度位置，刻度在下方
        self.sl.setTickPosition(QSlider.TicksBelow)
        # 设置刻度间隔
        self.sl.setTickInterval(5)
        layout.addWidget(self.sl)
        # 连接信号槽
        self.sl.valueChanged.connect(self.valuechange)
        self.setLayout(layout)
        print(self.sl.maximum(),type(self.sl.maximum()))


    def valuechange(self):
        print('current slider value=%s' % self.sl.value())
        size = self.sl.value()
        self.l1.setFont(QFont("Arial", size))

    def timerf(self):
        t=random.randint(10,50)

        self.sl.setValue(t)

if __name__ == '__main__':
    app = QApplication(sys.argv)
    demo = SliderDemo()
    demo.show()
    sys.exit(app.exec_())
# Out:
# 50 <class 'int'>
# current slider value=21
# current slider value=22
# current slider value=23
# current slider value=24
# current slider value=25
# current slider value=27
# current slider value=28
# current slider value=29
# current slider value=30
# current slider value=31
# current slider value=32
# current slider value=33
# current slider value=34
# current slider value=35
# current slider value=36
# current slider value=37
# current slider value=36
# current slider value=35
# current slider value=34
# current slider value=33
# current slider value=32
# current slider value=31
# current slider value=30
# current slider value=29
# current slider value=28
# current slider value=27
# current slider value=26
# current slider value=25
# current slider value=24
# current slider value=23
# current slider value=22
# current slider value=23
# current slider value=24
# current slider value=25
# current slider value=26
# current slider value=27
# current slider value=28
# current slider value=29
# current slider value=30
# current slider value=31
# current slider value=32
# current slider value=33
# current slider value=34
# current slider value=35
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# F:\IDE\ANACONDA\envs\pyqt5\lib\site-packages\IPython\core\interactiveshell.py:3386: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import scj.code.initialization as ini
ini.directory_ini()
# Out:
# G:\Lab_work\fault_detection_new\fault_detection\dir_test/data/device_list.yml

# %%
a="b"
print(type(a))
# Out:
# <class 'str'>

# %%
a={
    "b":2,
    "c":4
}
print(a["b"])
# Out:
# 2

# %% [markdown]
# # test camera

# %%
import sys
from PyQt5.QtCore import *
from PyQt5.QtGui import *
from PyQt5.QtWidgets import *
player = QMediaPlayer()

playlist = new QMediaPlaylist(player);
playlist->addMedia(QUrl("http://example.com/myclip1.mp4"));
playlist->addMedia(QUrl("http://example.com/myclip2.mp4"));

videoWidget = new QVideoWidget;
player->setVideoOutput(videoWidget);

videoWidget->show();
playlist->setCurrentIndex(1);
player->play();

# %%
# 获取系统可用的摄像头列表 test get_camera_list

import scj.code.device as device
import json
CamerasInfoList=json.loads(device.get_camera_list())
CamerasCount=CamerasInfoList["camera_num"]
CamerasList=[x["name"] for x in CamerasInfoList["camera_list"]]
print(CamerasList)
# Out:
# ['< cv2.VideoCapture 0000029EF4263B50>']

# %%
# test open_new_camera
import scj.code.device as device
device.open_new_camera("test_camera",0)
# Out:
# test_camera
# '{"code": 1, "message": "OK", "camera_name": "test_camera", "camera_path": "G:\\\\Lab_work\\\\fault_detection_new\\\\fault_detection\\\\dir_test/data/device/camera/test_camera"}'

# %%
import re
input_psd = input("请输入字符串")
test_str = re.search(r"\W",input_psd)
if test_str==None:
	print("没有没有真没有特殊字符")
else:
	print("该文本包含特殊字符")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [16], line 3
#       1 import re
#       2 input_psd = input("请输入字符串")
# ----> 3 test_str = re.search([],input_psd)
#       4 if test_str==None:
#       5 	print("没有没有真没有特殊字符")
#
# File F:\IDE\ANACONDA\envs\pyqt5\lib\re.py:201, in search(pattern, string, flags)
#     198 def search(pattern, string, flags=0):
#     199     """Scan through string looking for a match to the pattern, returning
#     200     a Match object, or None if no match was found."""
# --> 201     return _compile(pattern, flags).search(string)
#
# File F:\IDE\ANACONDA\envs\pyqt5\lib\re.py:294, in _compile(pattern, flags)
#     292     flags = flags.value
#     293 try:
# --> 294     return _cache[type(pattern), pattern, flags]
#     295 except KeyError:
#     296     pass
#
# TypeError: unhashable type: 'list'

# %%
import scj.code.device as device
print(device.delete_video_or_camera("test_camera",0))
# Out:
# {'test_camera': 'G:\\Lab_work\\fault_detection_new\\fault_detection\\dir_test/data/device/camera/test_camera', 'test_camera2': 'G:\\Lab_work\\fault_detection_new\\fault_detection\\dir_test/data/device/camera/test_camera2', 'test_camera3': 'G:\\Lab_work\\fault_detection_new\\fault_detection\\dir_test/data/device/camera/test_camera3', 'test_camera4': 'G:\\Lab_work\\fault_detection_new\\fault_detection\\dir_test/data/device/camera/test_camera4', 'test_camera5': 'G:\\Lab_work\\fault_detection_new\\fault_detection\\dir_test/data/device/camera/test_camera5'}
# {"code": 1, "message": "OK"}

# %%
import cv2

video_path = "C:\\Users\\11795\Videos\\中.mp4" # 225
# video_path = "C:\\Users\\11795\Videos\\test.mp4" # 2160
capture = cv2.VideoCapture(video_path)
frame_count = capture.get(cv2.CAP_PROP_FRAME_COUNT)
print(frame_count)
# Out:
# 2160.0

# %%
from PyQt5.QtMultimedia import QMediaPlayer,QMediaContent
from PyQt5 import QtCore
video_path = "file:///G:\Lab_work\\fault_detection_new\\fault_detection\dir_test/data/device/video/中/中.mp4"
player = QMediaPlayer()
player.setMedia(QMediaContent(QtCore.QUrl(video_path)))
def change(duration):
    print("播放了")
player.durationChanged.connect(change)
player.play()

# %%
import time
print(time.asctime())
# Out:
# Wed Oct 26 16:37:22 2022

# %%
from PyQt5.QtMultimedia import QMediaPlayer,QMediaContent
from PyQt5 import QtCore
video_path = "file:///G:\Lab_work\\fault_detection_new\\fault_detection\dir_test/data/device/video/中/中.mp4"
player = QMediaPlayer()
player.setMedia(None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [32], line 5
#       3 video_path = "file:///G:\Lab_work\\fault_detection_new\\fault_detection\dir_test/data/device/video/中/中.mp4"
#       4 player = QMediaPlayer()
# ----> 5 player.setMedia(None)
#
# TypeError: setMedia(self, QMediaContent, stream: QIODevice = None): argument 1 has unexpected type 'NoneType'

# %%
import sys
from PyQt5.QtCore import *
from PyQt5.QtGui import *
from PyQt5.QtWidgets import *
a=QUrl("http://example.com/myclip2.mp4")
print(a.toString())
